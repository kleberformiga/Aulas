# %% [markdown]
# ![title](LogoContabilidados.jpg)
#
#
# <h1 align = "center">Análise das Demonstrações Contábeis</h1>
#
#
# ## Visao das empresas
#
# <p>
# Aqui eu digo o que vamos fazer para o dia
# </p>
#
# \begin{align*}
# x^2 &= \frac{PL}{AT}
# \end{align*}
#
# # Aula 1
# * Itens

# %%
a <- rnorm(100)
hist(a)
# Out:
# Plot with title "Histogram of a"

# %%
summary(a)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# -1.80558 -0.52323  0.06041  0.13196  0.90974  2.14936

# %%
b <- 2

# %%
b
# Out:
# [1] 2

# %%
plot(a)
# Out:
# plot without title
